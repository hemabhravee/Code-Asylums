# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ds = pd.read_csv("Iris.csv")

# %%
ds.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
import seaborn as sns
import matplotlib

# %%
ds.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df = ds[["SepalWidthCm","PetalLengthCm","Species"]]

# %%
df.Species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
c = np.array

# %%
sns.pairplot(df).add_legend()
# Out:
# /home/hemabh/.local/lib/python3.6/site-packages/seaborn/axisgrid.py:88: UserWarning: The handle <matplotlib.patches.Patch object at 0x7f7d173fcdd8> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   **kwargs)

# %%
df.corr()
# Out:
#                SepalWidthCm  PetalLengthCm
# SepalWidthCm       1.000000      -0.420516
# PetalLengthCm     -0.420516       1.000000

# %%
sns.FacetGrid(df,hue="Species",height =6).map(plt.scatter,"SepalWidthCm","PetalLengthCm").add_legend()

# %%
#iris-setosa is easily seperable - very low petal length & high sepal width
#versicolor and virginica have similar sepal Width but versicolor has lower petal length

# %%
sns.FacetGrid(ds,hue="Species",height =6).map(plt.scatter,"PetalWidthCm","SepalLengthCm").add_legend()

# %%
sns.FacetGrid(ds,hue="Species",height =6).map(plt.scatter,"PetalWidthCm","PetalLengthCm").add_legend()

# %%
df.plot.kde()
